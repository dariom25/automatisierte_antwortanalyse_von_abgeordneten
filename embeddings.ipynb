# %% [markdown]
# # Word Embeddings Approach

# %%
import fasttext.util
import pandas as pd

# %%
df_data = pd.read_csv("data/stratified_sample_cleaned.csv")

# %%
fasttext.util.download_model("de", if_exists="ignore")
ft = fasttext.load_model("model/cc.de.300.bin")
# Out:
# ...
#  (100.00%) [==================================================>]                                                 ]=>                                                 ]=>                                                 ]==>                                                ]==>                                                ]=====>                                             ]=====>                                             ]======>                                            ]======>                                            ]======>                                            ]======>                                            ]======>                                            ]=========>                                         ]==========>                                        ]==========>                                        ]============>                                      ]=============>                                     ]==============>                                    ]
# ...
